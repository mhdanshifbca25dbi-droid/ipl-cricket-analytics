# %%
import sqlite3
import pandas as pd

con = sqlite3.connect("../data/raw/ipl.db")

def q(sql):
    return pd.read_sql(sql, con)

# %%
q("SELECT COUNT(*) FROM matches;")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Desktop\ipl-cricket-analytics\.venv\Lib\site-packages\pandas\io\sql.py:2745, in SQLiteDatabase.execute(self, sql, params)
#    2744 try:
# -> 2745     cur.execute(sql, *args)
#    2746     return cur
#
# OperationalError: no such table: matches
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 q("SELECT COUNT(*) FROM matches;")
#
# Cell In[2], line 7, in q(sql)
#       6 def q(sql):
# ----> 7     return pd.read_sql(sql, con)
#
# File ~\Desktop\ipl-cricket-analytics\.venv\Lib\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
import os

print(os.path.exists("../data/raw/ipl.db"))
print(os.listdir("../data/raw"))
# Out:
# True
# ['.gitkeep', 'ipl.db', 'test.csv']

# %%
q("""
SELECT name
FROM sqlite_master
WHERE type = 'table';
""")
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []
